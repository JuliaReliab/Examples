# %%
using Pkg
Pkg.add(PackageSpec(url="https://github.com/JuliaReliab/Origin.jl.git"))
Pkg.add(PackageSpec(url="https://github.com/JuliaReliab/Deformula.jl.git"))
Pkg.add(PackageSpec(url="https://github.com/JuliaReliab/SparseMatrix.jl.git"))
Pkg.add(PackageSpec(url="https://github.com/JuliaReliab/NMarkov.jl.git"))
Pkg.add(PackageSpec(url="https://github.com/JuliaReliab/SymbolicDiff.jl.git"))
Pkg.add(PackageSpec(url="https://github.com/JuliaReliab/SymbolicMarkov.jl.git"))
# Pkg.add(PackageSpec(url="https://github.com/JuliaReliab/PhaseTypeDistributions.jl.git"))
# Out:
#     Updating git-repo `https://github.com/JuliaReliab/Origin.jl.git`
#    Resolving package versions...
#   No Changes to `/opt/julia/environments/v1.6/Project.toml`
#   No Changes to `/opt/julia/environments/v1.6/Manifest.toml`
#     Updating git-repo `https://github.com/JuliaReliab/Deformula.jl.git`
#    Resolving package versions...
#   No Changes to `/opt/julia/environments/v1.6/Project.toml`
#   No Changes to `/opt/julia/environments/v1.6/Manifest.toml`
#     Updating git-repo `https://github.com/JuliaReliab/SparseMatrix.jl.git`
#    Resolving package versions...
# Unsatisfiable requirements detected for package SparseMatrix [b2a93422]:
#  SparseMatrix [b2a93422] log:
#  ├─possible versions are: 0.3.3 or uninstalled
#  ├─restricted to versions 0.2.3-0.2 by PhaseTypeDistributions [6af5a0ae] — no versions left
#  │ └─PhaseTypeDistributions [6af5a0ae] log:
#  │   ├─possible versions are: 0.2.6 or uninstalled
#  │   └─PhaseTypeDistributions [6af5a0ae] is fixed to version 0.2.6
#  └─SparseMatrix [b2a93422] is fixed to version 0.3.3
#
# Stacktrace:
#   [1] check_constraints(graph::Pkg.Resolve.Graph)
#     @ Pkg.Resolve /buildworker/worker/package_linux64/build/usr/share/julia/stdlib/v1.6/Pkg/src/Resolve/graphtype.jl:978
#   [2] Pkg.Resolve.Graph(versions::Dict{Base.UUID, Set{VersionNumber}}, deps::Dict{Base.UUID, Dict{VersionNumber, Dict{String, Base.UUID}}}, compat::Dict{Base.UUID, Dict{VersionNumber, Dict{String, Pkg.Types.VersionSpec}}}, uuid_to_name::Dict{Base.UUID, String}, reqs::Dict{Base.UUID, Pkg.Types.VersionSpec}, fixed::Dict{Base.UUID, Pkg.Resolve.Fixed}, verbose::Bool, julia_version::VersionNumber)
#     @ Pkg.Resolve /buildworker/worker/package_linux64/build/usr/share/julia/stdlib/v1.6/Pkg/src/Resolve/graphtype.jl:371
#   [3] deps_graph(ctx::Pkg.Types.Context, uuid_to_name::Dict{Base.UUID, String}, reqs::Dict{Base.UUID, Pkg.Types.VersionSpec}, fixed::Dict{Base.UUID, Pkg.Resolve.Fixed})
#     @ Pkg.Operations /buildworker/worker/package_linux64/build/usr/share/julia/stdlib/v1.6/Pkg/src/Operations.jl:537
#   [4] resolve_versions!(ctx::Pkg.Types.Context, pkgs::Vector{Pkg.Types.PackageSpec})
#     @ Pkg.Operations /buildworker/worker/package_linux64/build/usr/share/julia/stdlib/v1.6/Pkg/src/Operations.jl:407
#   [5] targeted_resolve(ctx::Pkg.Types.Context, pkgs::Vector{Pkg.Types.PackageSpec}, preserve::Pkg.Types.PreserveLevel)
#     @ Pkg.Operations /buildworker/worker/package_linux64/build/usr/share/julia/stdlib/v1.6/Pkg/src/Operations.jl:1214
#   [6] tiered_resolve(ctx::Pkg.Types.Context, pkgs::Vector{Pkg.Types.PackageSpec})
#     @ Pkg.Operations /buildworker/worker/package_linux64/build/usr/share/julia/stdlib/v1.6/Pkg/src/Operations.jl:1200
#   [7] _resolve
#     @ /buildworker/worker/package_linux64/build/usr/share/julia/stdlib/v1.6/Pkg/src/Operations.jl:1220 [inlined]
#   [8] add(ctx::Pkg.Types.Context, pkgs::Vector{Pkg.Types.PackageSpec}, new_git::Vector{Base.UUID}; preserve::Pkg.Types.PreserveLevel, platform::Base.BinaryPlatforms.Platform)
#     @ Pkg.Operations /buildworker/worker/package_linux64/build/usr/share/julia/stdlib/v1.6/Pkg/src/Operations.jl:1235
#   [9] add(ctx::Pkg.Types.Context, pkgs::Vector{Pkg.Types.PackageSpec}; preserve::Pkg.Types.PreserveLevel, platform::Base.BinaryPlatforms.Platform, kwargs::Base.Iterators.Pairs{Symbol, IJulia.IJuliaStdio{Base.PipeEndpoint}, Tuple{Symbol}, NamedTuple{(:io,), Tuple{IJulia.IJuliaStdio{Base.PipeEndpoint}}}})
#     @ Pkg.API /buildworker/worker/package_linux64/build/usr/share/julia/stdlib/v1.6/Pkg/src/API.jl:204
#  [10] add(pkgs::Vector{Pkg.Types.PackageSpec}; io::IJulia.IJuliaStdio{Base.PipeEndpoint}, kwargs::Base.Iterators.Pairs{Union{}, Union{}, Tuple{}, NamedTuple{(), Tuple{}}})
#     @ Pkg.API /buildworker/worker/package_linux64/build/usr/share/julia/stdlib/v1.6/Pkg/src/API.jl:80
#  [11] add(pkgs::Vector{Pkg.Types.PackageSpec})
#     @ Pkg.API /buildworker/worker/package_linux64/build/usr/share/julia/stdlib/v1.6/Pkg/src/API.jl:78
#  [12] #add#22
#     @ /buildworker/worker/package_linux64/build/usr/share/julia/stdlib/v1.6/Pkg/src/API.jl:75 [inlined]
#  [13] add(pkg::Pkg.Types.PackageSpec)
#     @ Pkg.API /buildworker/worker/package_linux64/build/usr/share/julia/stdlib/v1.6/Pkg/src/API.jl:75
#  [14] top-level scope
#     @ In[3]:4
#  [15] eval
#     @ ./boot.jl:360 [inlined]
#  [16] include_string(mapexpr::typeof(REPL.softscope), mod::Module, code::String, filename::String)
#     @ Base ./loading.jl:1116

# %%
using SparseArrays
using NMarkov
using SymbolicDiff
using SymbolicMarkov
using Plots
using Distributions
using Random
# Out:
# ┌ Info: Precompiling NMarkov [c5cca998-98d3-11ea-1288-bb4300628a81]
# └ @ Base loading.jl:1342
# ┌ Warning: Module JLLWrappers with build ID 14418454654031536 is missing from the cache.
# │ This may mean JLLWrappers [692b3bcd-3c85-4b1f-b108-f13ce0eb3210] does not support precompilation but is imported by a module that does.
# └ @ Base loading.jl:1030
# ┌ Warning: Module JLLWrappers with build ID 14418454654031536 is missing from the cache.
# │ This may mean JLLWrappers [692b3bcd-3c85-4b1f-b108-f13ce0eb3210] does not support precompilation but is imported by a module that does.
# └ @ Base loading.jl:1030
# ┌ Warning: Module JLLWrappers with build ID 14418454654031536 is missing from the cache.
# │ This may mean JLLWrappers [692b3bcd-3c85-4b1f-b108-f13ce0eb3210] does not support precompilation but is imported by a module that does.
# └ @ Base loading.jl:1030
# ┌ Warning: Module JLLWrappers with build ID 14418454654031536 is missing from the cache.
# │ This may mean JLLWrappers [692b3bcd-3c85-4b1f-b108-f13ce0eb3210] does not support precompilation but is imported by a module that does.
# └ @ Base loading.jl:1030
# ┌ Warning: Module JLLWrappers with build ID 14418454654031536 is missing from the cache.
# │ This may mean JLLWrappers [692b3bcd-3c85-4b1f-b108-f13ce0eb3210] does not support precompilation but is imported by a module that does.
# └ @ Base loading.jl:1030
# ┌ Warning: Module JLLWrappers with build ID 14418454654031536 is missing from the cache.
# │ This may mean JLLWrappers [692b3bcd-3c85-4b1f-b108-f13ce0eb3210] does not support precompilation but is imported by a module that does.
# └ @ Base loading.jl:1030
# ┌ Warning: Module JLLWrappers with build ID 14418454654031536 is missing from the cache.
# │ This may mean JLLWrappers [692b3bcd-3c85-4b1f-b108-f13ce0eb3210] does not support precompilation but is imported by a module that does.
# └ @ Base loading.jl:1030
# ┌ Warning: Module JLLWrappers with build ID 14418454654031536 is missing from the cache.
# │ This may mean JLLWrappers [692b3bcd-3c85-4b1f-b108-f13ce0eb3210] does not support precompilation but is imported by a module that does.
# └ @ Base loading.jl:1030
# ┌ Warning: Module JLLWrappers with build ID 14418454654031536 is missing from the cache.
# │ This may mean JLLWrappers [692b3bcd-3c85-4b1f-b108-f13ce0eb3210] does not support precompilation but is imported by a module that does.
# └ @ Base loading.jl:1030
# ┌ Warning: Module JLLWrappers with build ID 14418454654031536 is missing from the cache.
# │ This may mean JLLWrappers [692b3bcd-3c85-4b1f-b108-f13ce0eb3210] does not support precompilation but is imported by a module that does.
# └ @ Base loading.jl:1030
# ┌ Warning: Module JLLWrappers with build ID 14418454654031536 is missing from the cache.
# │ This may mean JLLWrappers [692b3bcd-3c85-4b1f-b108-f13ce0eb3210] does not support precompilation but is imported by a module that does.
# └ @ Base loading.jl:1030
# ┌ Warning: Module JLLWrappers with build ID 14418454654031536 is missing from the cache.
# │ This may mean JLLWrappers [692b3bcd-3c85-4b1f-b108-f13ce0eb3210] does not support precompilation but is imported by a module that does.
# └ @ Base loading.jl:1030
# ┌ Warning: Module JLLWrappers with build ID 14418454654031536 is missing from the cache.
# │ This may mean JLLWrappers [692b3bcd-3c85-4b1f-b108-f13ce0eb3210] does not support precompilation but is imported by a module that does.
# └ @ Base loading.jl:1030
# ┌ Warning: Module JLLWrappers with build ID 14418454654031536 is missing from the cache.
# │ This may mean JLLWrappers [692b3bcd-3c85-4b1f-b108-f13ce0eb3210] does not support precompilation but is imported by a module that does.
# └ @ Base loading.jl:1030
# ┌ Warning: Module JLLWrappers with build ID 14418454654031536 is missing from the cache.
# │ This may mean JLLWrappers [692b3bcd-3c85-4b1f-b108-f13ce0eb3210] does not support precompilation but is imported by a module that does.
# └ @ Base loading.jl:1030
# ┌ Warning: Module JLLWrappers with build ID 14418454654031536 is missing from the cache.
# │ This may mean JLLWrappers [692b3bcd-3c85-4b1f-b108-f13ce0eb3210] does not support precompilation but is imported by a module that does.
# └ @ Base loading.jl:1030
# ┌ Info: Skipping precompilation since __precompile__(false). Importing NMarkov [c5cca998-98d3-11ea-1288-bb4300628a81].
# └ @ Base loading.jl:1047
# ┌ Info: Precompiling Distributions [31c24e10-a181-5473-b8eb-7969acd0382f]
# └ @ Base loading.jl:1342
# ┌ Warning: Module JLLWrappers with build ID 14418454654031536 is missing from the cache.
# │ This may mean JLLWrappers [692b3bcd-3c85-4b1f-b108-f13ce0eb3210] does not support precompilation but is imported by a module that does.
# └ @ Base loading.jl:1030
# ┌ Warning: Module JLLWrappers with build ID 14418454654031536 is missing from the cache.
# │ This may mean JLLWrappers [692b3bcd-3c85-4b1f-b108-f13ce0eb3210] does not support precompilation but is imported by a module that does.
# └ @ Base loading.jl:1030
# ┌ Warning: Module JLLWrappers with build ID 14418454654031536 is missing from the cache.
# │ This may mean JLLWrappers [692b3bcd-3c85-4b1f-b108-f13ce0eb3210] does not support precompilation but is imported by a module that does.
# └ @ Base loading.jl:1030
# ┌ Warning: Module JLLWrappers with build ID 14418454654031536 is missing from the cache.
# │ This may mean JLLWrappers [692b3bcd-3c85-4b1f-b108-f13ce0eb3210] does not support precompilation but is imported by a module that does.
# └ @ Base loading.jl:1030
# ┌ Warning: Module JLLWrappers with build ID 14418454654031536 is missing from the cache.
# │ This may mean JLLWrappers [692b3bcd-3c85-4b1f-b108-f13ce0eb3210] does not support precompilation but is imported by a module that does.
# └ @ Base loading.jl:1030
# ┌ Warning: Module JLLWrappers with build ID 14418454654031536 is missing from the cache.
# │ This may mean JLLWrappers [692b3bcd-3c85-4b1f-b108-f13ce0eb3210] does not support precompilation but is imported by a module that does.
# └ @ Base loading.jl:1030
# ┌ Warning: Module JLLWrappers with build ID 14418454654031536 is missing from the cache.
# │ This may mean JLLWrappers [692b3bcd-3c85-4b1f-b108-f13ce0eb3210] does not support precompilation but is imported by a module that does.
# └ @ Base loading.jl:1030
# ┌ Warning: Module JLLWrappers with build ID 14418454654031536 is missing from the cache.
# │ This may mean JLLWrappers [692b3bcd-3c85-4b1f-b108-f13ce0eb3210] does not support precompilation but is imported by a module that does.
# └ @ Base loading.jl:1030
# ┌ Info: Skipping precompilation since __precompile__(false). Importing Distributions [31c24e10-a181-5473-b8eb-7969acd0382f].
# └ @ Base loading.jl:1047
# ┌ Info: Precompiling StatsFuns [4c63d2b9-4356-54db-8cca-17b64c39e42c]
# └ @ Base loading.jl:1342
# ┌ Warning: Module JLLWrappers with build ID 14418454654031536 is missing from the cache.
# │ This may mean JLLWrappers [692b3bcd-3c85-4b1f-b108-f13ce0eb3210] does not support precompilation but is imported by a module that does.
# └ @ Base loading.jl:1030
# ┌ Warning: Module JLLWrappers with build ID 14418454654031536 is missing from the cache.
# │ This may mean JLLWrappers [692b3bcd-3c85-4b1f-b108-f13ce0eb3210] does not support precompilation but is imported by a module that does.
# └ @ Base loading.jl:1030
# ┌ Warning: Module JLLWrappers with build ID 14418454654031536 is missing from the cache.
# │ This may mean JLLWrappers [692b3bcd-3c85-4b1f-b108-f13ce0eb3210] does not support precompilation but is imported by a module that does.
# └ @ Base loading.jl:1030
# ┌ Warning: Module JLLWrappers with build ID 14418454654031536 is missing from the cache.
# │ This may mean JLLWrappers [692b3bcd-3c85-4b1f-b108-f13ce0eb3210] does not support precompilation but is imported by a module that does.
# └ @ Base loading.jl:1030
# ┌ Info: Skipping precompilation since __precompile__(false). Importing StatsFuns [4c63d2b9-4356-54db-8cca-17b64c39e42c].
# └ @ Base loading.jl:1047
# ┌ Info: Precompiling SpecialFunctions [276daf66-3868-5448-9aa4-cd146d93841b]
# └ @ Base loading.jl:1342
# ┌ Warning: Module JLLWrappers with build ID 14418454654031536 is missing from the cache.
# │ This may mean JLLWrappers [692b3bcd-3c85-4b1f-b108-f13ce0eb3210] does not support precompilation but is imported by a module that does.
# └ @ Base loading.jl:1030
# ┌ Warning: Module JLLWrappers with build ID 14418454654031536 is missing from the cache.
# │ This may mean JLLWrappers [692b3bcd-3c85-4b1f-b108-f13ce0eb3210] does not support precompilation but is imported by a module that does.
# └ @ Base loading.jl:1030
# ┌ Info: Skipping precompilation since __precompile__(false). Importing SpecialFunctions [276daf66-3868-5448-9aa4-cd146d93841b].
# └ @ Base loading.jl:1047
# ┌ Info: Precompiling OpenSpecFun_jll [efe28fd5-8261-553b-a9e1-b2916fc3738e]
# └ @ Base loading.jl:1342
# ┌ Warning: Module JLLWrappers with build ID 14418454654031536 is missing from the cache.
# │ This may mean JLLWrappers [692b3bcd-3c85-4b1f-b108-f13ce0eb3210] does not support precompilation but is imported by a module that does.
# └ @ Base loading.jl:1030
# ┌ Info: Skipping precompilation since __precompile__(false). Importing OpenSpecFun_jll [efe28fd5-8261-553b-a9e1-b2916fc3738e].
# └ @ Base loading.jl:1047
# ┌ Info: Precompiling Rmath [79098fc4-a85e-5d69-aa6a-4863f24498fa]
# └ @ Base loading.jl:1342
# ┌ Warning: Module JLLWrappers with build ID 14418454654031536 is missing from the cache.
# │ This may mean JLLWrappers [692b3bcd-3c85-4b1f-b108-f13ce0eb3210] does not support precompilation but is imported by a module that does.
# └ @ Base loading.jl:1030
# ┌ Warning: Module JLLWrappers with build ID 14418454654031536 is missing from the cache.
# │ This may mean JLLWrappers [692b3bcd-3c85-4b1f-b108-f13ce0eb3210] does not support precompilation but is imported by a module that does.
# └ @ Base loading.jl:1030
# ┌ Info: Skipping precompilation since __precompile__(false). Importing Rmath [79098fc4-a85e-5d69-aa6a-4863f24498fa].
# └ @ Base loading.jl:1047
# ┌ Info: Precompiling Rmath_jll [f50d1b31-88e8-58de-be2c-1cc44531875f]
# └ @ Base loading.jl:1342
# ┌ Warning: Module JLLWrappers with build ID 14418454654031536 is missing from the cache.
# │ This may mean JLLWrappers [692b3bcd-3c85-4b1f-b108-f13ce0eb3210] does not support precompilation but is imported by a module that does.
# └ @ Base loading.jl:1030
# ┌ Info: Skipping precompilation since __precompile__(false). Importing Rmath_jll [f50d1b31-88e8-58de-be2c-1cc44531875f].
# └ @ Base loading.jl:1047
# ┌ Info: Precompiling HypergeometricFunctions [34004b35-14d8-5ef3-9330-4cdb6864b03a]
# └ @ Base loading.jl:1342
# ┌ Warning: Module SpecialFunctions with build ID 23994285156318024 is missing from the cache.
# │ This may mean SpecialFunctions [276daf66-3868-5448-9aa4-cd146d93841b] does not support precompilation but is imported by a module that does.
# └ @ Base loading.jl:1030
# ┌ Warning: Module SpecialFunctions with build ID 23994285156318024 is missing from the cache.
# │ This may mean SpecialFunctions [276daf66-3868-5448-9aa4-cd146d93841b] does not support precompilation but is imported by a module that does.
# └ @ Base loading.jl:1030
# ┌ Info: Skipping precompilation since __precompile__(false). Importing HypergeometricFunctions [34004b35-14d8-5ef3-9330-4cdb6864b03a].
# └ @ Base loading.jl:1047
# ┌ Info: Precompiling DualNumbers [fa6b7ba4-c1ee-5f82-b5fc-ecf0adba8f74]
# └ @ Base loading.jl:1342
# ┌ Warning: Module SpecialFunctions with build ID 23994285156318024 is missing from the cache.
# │ This may mean SpecialFunctions [276daf66-3868-5448-9aa4-cd146d93841b] does not support precompilation but is imported by a module that does.
# └ @ Base loading.jl:1030
# ┌ Info: Skipping precompilation since __precompile__(false). Importing DualNumbers [fa6b7ba4-c1ee-5f82-b5fc-ecf0adba8f74].
# └ @ Base loading.jl:1047
# ┌ Info: Precompiling SymbolicMarkov [29f2b557-c746-4a93-aecc-96f24fec2756]
# └ @ Base loading.jl:1342
# ┌ Warning: Module NMarkov with build ID 23994275934425559 is missing from the cache.
# │ This may mean NMarkov [c5cca998-98d3-11ea-1288-bb4300628a81] does not support precompilation but is imported by a module that does.
# └ @ Base loading.jl:1030
# ┌ Info: Skipping precompilation since __precompile__(false). Importing SymbolicMarkov [29f2b557-c746-4a93-aecc-96f24fec2756].
# └ @ Base loading.jl:1047
# ┌ Info: Precompiling Plots [91a5bcdd-55d7-5caf-9e0b-520d859cae80]
# └ @ Base loading.jl:1342
# ┌ Warning: Module JLLWrappers with build ID 14418454654031536 is missing from the cache.
# │ This may mean JLLWrappers [692b3bcd-3c85-4b1f-b108-f13ce0eb3210] does not support precompilation but is imported by a module that does.
# └ @ Base loading.jl:1030
# ┌ Warning: Module JLLWrappers with build ID 14418454654031536 is missing from the cache.
# │ This may mean JLLWrappers [692b3bcd-3c85-4b1f-b108-f13ce0eb3210] does not support precompilation but is imported by a module that does.
# └ @ Base loading.jl:1030
# ┌ Warning: Module JLLWrappers with build ID 14418454654031536 is missing from the cache.
# │ This may mean JLLWrappers [692b3bcd-3c85-4b1f-b108-f13ce0eb3210] does not support precompilation but is imported by a module that does.
# └ @ Base loading.jl:1030
# ┌ Warning: Module JLLWrappers with build ID 14418454654031536 is missing from the cache.
# │ This may mean JLLWrappers [692b3bcd-3c85-4b1f-b108-f13ce0eb3210] does not support precompilation but is imported by a module that does.
# └ @ Base loading.jl:1030
# ┌ Info: Skipping precompilation since __precompile__(false). Importing Plots [91a5bcdd-55d7-5caf-9e0b-520d859cae80].
# └ @ Base loading.jl:1047
# ┌ Info: Precompiling GeometryBasics [5c1252a2-5f33-56bf-86c9-59e7332b4326]
# └ @ Base loading.jl:1342
# ┌ Warning: Module JLLWrappers with build ID 14418454654031536 is missing from the cache.
# │ This may mean JLLWrappers [692b3bcd-3c85-4b1f-b108-f13ce0eb3210] does not support precompilation but is imported by a module that does.
# └ @ Base loading.jl:1030
# ┌ Warning: Module JLLWrappers with build ID 14418454654031536 is missing from the cache.
# │ This may mean JLLWrappers [692b3bcd-3c85-4b1f-b108-f13ce0eb3210] does not support precompilation but is imported by a module that does.
# └ @ Base loading.jl:1030
# ┌ Info: Skipping precompilation since __precompile__(false). Importing GeometryBasics [5c1252a2-5f33-56bf-86c9-59e7332b4326].
# └ @ Base loading.jl:1047
# ┌ Info: Precompiling EarCut_jll [5ae413db-bbd1-5e63-b57d-d24a61df00f5]
# └ @ Base loading.jl:1342
# ┌ Warning: Module JLLWrappers with build ID 14418454654031536 is missing from the cache.
# │ This may mean JLLWrappers [692b3bcd-3c85-4b1f-b108-f13ce0eb3210] does not support precompilation but is imported by a module that does.
# └ @ Base loading.jl:1030
# ┌ Info: Skipping precompilation since __precompile__(false). Importing EarCut_jll [5ae413db-bbd1-5e63-b57d-d24a61df00f5].
# └ @ Base loading.jl:1047
# ┌ Info: Precompiling FFMPEG [c87230d0-a227-11e9-1b43-d7ebe4e7570a]
# └ @ Base loading.jl:1342
# ┌ Warning: Module JLLWrappers with build ID 14418454654031536 is missing from the cache.
# │ This may mean JLLWrappers [692b3bcd-3c85-4b1f-b108-f13ce0eb3210] does not support precompilation but is imported by a module that does.
# └ @ Base loading.jl:1030
# ┌ Warning: Module JLLWrappers with build ID 14418454654031536 is missing from the cache.
# │ This may mean JLLWrappers [692b3bcd-3c85-4b1f-b108-f13ce0eb3210] does not support precompilation but is imported by a module that does.
# └ @ Base loading.jl:1030
# ┌ Info: Skipping precompilation since __precompile__(false). Importing FFMPEG [c87230d0-a227-11e9-1b43-d7ebe4e7570a].
# └ @ Base loading.jl:1047
# ┌ Info: Precompiling FFMPEG_jll [b22a6f82-2f65-5046-a5b2-351ab43fb4e5]
# └ @ Base loading.jl:1342
# ┌ Warning: Module JLLWrappers with build ID 14418454654031536 is missing from the cache.
# │ This may mean JLLWrappers [692b3bcd-3c85-4b1f-b108-f13ce0eb3210] does not support precompilation but is imported by a module that does.
# └ @ Base loading.jl:1030
# ┌ Info: Skipping precompilation since __precompile__(false). Importing FFMPEG_jll [b22a6f82-2f65-5046-a5b2-351ab43fb4e5].
# └ @ Base loading.jl:1047
# ┌ Info: Precompiling libass_jll [0ac62f75-1d6f-5e53-bd7c-93b484bb37c0]
# └ @ Base loading.jl:1342
# ┌ Warning: Module JLLWrappers with build ID 14418454654031536 is missing from the cache.
# │ This may mean JLLWrappers [692b3bcd-3c85-4b1f-b108-f13ce0eb3210] does not support precompilation but is imported by a module that does.
# └ @ Base loading.jl:1030
# ┌ Info: Skipping precompilation since __precompile__(false). Importing libass_jll [0ac62f75-1d6f-5e53-bd7c-93b484bb37c0].
# └ @ Base loading.jl:1047
# ┌ Info: Precompiling FreeType2_jll [d7e528f0-a631-5988-bf34-fe36492bcfd7]
# └ @ Base loading.jl:1342
# ┌ Warning: Module JLLWrappers with build ID 14418454654031536 is missing from the cache.
# │ This may mean JLLWrappers [692b3bcd-3c85-4b1f-b108-f13ce0eb3210] does not support precompilation but is imported by a module that does.
# └ @ Base loading.jl:1030
# ┌ Info: Skipping precompilation since __precompile__(false). Importing FreeType2_jll [d7e528f0-a631-5988-bf34-fe36492bcfd7].
# └ @ Base loading.jl:1047
# ┌ Info: Precompiling Bzip2_jll [6e34b625-4abd-537c-b88f-471c36dfa7a0]
# └ @ Base loading.jl:1342
# ┌ Warning: Module JLLWrappers with build ID 14418454654031536 is missing from the cache.
# │ This may mean JLLWrappers [692b3bcd-3c85-4b1f-b108-f13ce0eb3210] does not support precompilation but is imported by a module that does.
# └ @ Base loading.jl:1030
# ┌ Info: Skipping precompilation since __precompile__(false). Importing Bzip2_jll [6e34b625-4abd-537c-b88f-471c36dfa7a0].
# └ @ Base loading.jl:1047
# ┌ Info: Precompiling FriBidi_jll [559328eb-81f9-559d-9380-de523a88c83c]
# └ @ Base loading.jl:1342
# ┌ Warning: Module JLLWrappers with build ID 14418454654031536 is missing from the cache.
# │ This may mean JLLWrappers [692b3bcd-3c85-4b1f-b108-f13ce0eb3210] does not support precompilation but is imported by a module that does.
# └ @ Base loading.jl:1030
# ┌ Info: Skipping precompilation since __precompile__(false). Importing FriBidi_jll [559328eb-81f9-559d-9380-de523a88c83c].
# └ @ Base loading.jl:1047
# ┌ Info: Precompiling HarfBuzz_jll [2e76f6c2-a576-52d4-95c1-20adfe4de566]
# └ @ Base loading.jl:1342
# ┌ Warning: Module JLLWrappers with build ID 14418454654031536 is missing from the cache.
# │ This may mean JLLWrappers [692b3bcd-3c85-4b1f-b108-f13ce0eb3210] does not support precompilation but is imported by a module that does.
# └ @ Base loading.jl:1030
# ┌ Info: Skipping precompilation since __precompile__(false). Importing HarfBuzz_jll [2e76f6c2-a576-52d4-95c1-20adfe4de566].
# └ @ Base loading.jl:1047
# ┌ Info: Precompiling Cairo_jll [83423d85-b0ee-5818-9007-b63ccbeb887a]
# └ @ Base loading.jl:1342
# ┌ Warning: Module JLLWrappers with build ID 14418454654031536 is missing from the cache.
# │ This may mean JLLWrappers [692b3bcd-3c85-4b1f-b108-f13ce0eb3210] does not support precompilation but is imported by a module that does.
# └ @ Base loading.jl:1030
# ┌ Info: Skipping precompilation since __precompile__(false). Importing Cairo_jll [83423d85-b0ee-5818-9007-b63ccbeb887a].
# └ @ Base loading.jl:1047
# ┌ Info: Precompiling Glib_jll [7746bdde-850d-59dc-9ae8-88ece973131d]
# └ @ Base loading.jl:1342
# ┌ Warning: Module JLLWrappers with build ID 14418454654031536 is missing from the cache.
# │ This may mean JLLWrappers [692b3bcd-3c85-4b1f-b108-f13ce0eb3210] does not support precompilation but is imported by a module that does.
# └ @ Base loading.jl:1030
# ┌ Info: Skipping precompilation since __precompile__(false). Importing Glib_jll [7746bdde-850d-59dc-9ae8-88ece973131d].
# └ @ Base loading.jl:1047
# ┌ Info: Precompiling Libiconv_jll [94ce4f54-9a6c-5748-9c1c-f9c7231a4531]
# └ @ Base loading.jl:1342
# ┌ Warning: Module JLLWrappers with build ID 14418454654031536 is missing from the cache.
# │ This may mean JLLWrappers [692b3bcd-3c85-4b1f-b108-f13ce0eb3210] does not support precompilation but is imported by a module that does.
# └ @ Base loading.jl:1030
# ┌ Info: Skipping precompilation since __precompile__(false). Importing Libiconv_jll [94ce4f54-9a6c-5748-9c1c-f9c7231a4531].
# └ @ Base loading.jl:1047
# ┌ Info: Precompiling Libffi_jll [e9f186c6-92d2-5b65-8a66-fee21dc1b490]
# └ @ Base loading.jl:1342
# ┌ Warning: Module JLLWrappers with build ID 14418454654031536 is missing from the cache.
# │ This may mean JLLWrappers [692b3bcd-3c85-4b1f-b108-f13ce0eb3210] does not support precompilation but is imported by a module that does.
# └ @ Base loading.jl:1030
# ┌ Info: Skipping precompilation since __precompile__(false). Importing Libffi_jll [e9f186c6-92d2-5b65-8a66-fee21dc1b490].
# └ @ Base loading.jl:1047
# ┌ Info: Precompiling Gettext_jll [78b55507-aeef-58d4-861c-77aaff3498b1]
# └ @ Base loading.jl:1342
# ┌ Warning: Module JLLWrappers with build ID 14418454654031536 is missing from the cache.
# │ This may mean JLLWrappers [692b3bcd-3c85-4b1f-b108-f13ce0eb3210] does not support precompilation but is imported by a module that does.
# └ @ Base loading.jl:1030
# ┌ Info: Skipping precompilation since __precompile__(false). Importing Gettext_jll [78b55507-aeef-58d4-861c-77aaff3498b1].
# └ @ Base loading.jl:1047
# ┌ Info: Precompiling XML2_jll [02c8fc9c-b97f-50b9-bbe4-9be30ff0a78a]
# └ @ Base loading.jl:1342
# ┌ Warning: Module JLLWrappers with build ID 14418454654031536 is missing from the cache.
# │ This may mean JLLWrappers [692b3bcd-3c85-4b1f-b108-f13ce0eb3210] does not support precompilation but is imported by a module that does.
# └ @ Base loading.jl:1030
# ┌ Info: Skipping precompilation since __precompile__(false). Importing XML2_jll [02c8fc9c-b97f-50b9-bbe4-9be30ff0a78a].
# └ @ Base loading.jl:1047
# ┌ Info: Precompiling PCRE_jll [2f80f16e-611a-54ab-bc61-aa92de5b98fc]
# └ @ Base loading.jl:1342
# ┌ Warning: Module JLLWrappers with build ID 14418454654031536 is missing from the cache.
# │ This may mean JLLWrappers [692b3bcd-3c85-4b1f-b108-f13ce0eb3210] does not support precompilation but is imported by a module that does.
# └ @ Base loading.jl:1030
# ┌ Info: Skipping precompilation since __precompile__(false). Importing PCRE_jll [2f80f16e-611a-54ab-bc61-aa92de5b98fc].
# └ @ Base loading.jl:1047
# ┌ Info: Precompiling Libmount_jll [4b2f31a3-9ecc-558c-b454-b3730dcb73e9]
# └ @ Base loading.jl:1342
# ┌ Warning: Module JLLWrappers with build ID 14418454654031536 is missing from the cache.
# │ This may mean JLLWrappers [692b3bcd-3c85-4b1f-b108-f13ce0eb3210] does not support precompilation but is imported by a module that does.
# └ @ Base loading.jl:1030
# ┌ Info: Skipping precompilation since __precompile__(false). Importing Libmount_jll [4b2f31a3-9ecc-558c-b454-b3730dcb73e9].
# └ @ Base loading.jl:1047
# ┌ Info: Precompiling Pixman_jll [30392449-352a-5448-841d-b1acce4e97dc]
# └ @ Base loading.jl:1342
# ┌ Warning: Module JLLWrappers with build ID 14418454654031536 is missing from the cache.
# │ This may mean JLLWrappers [692b3bcd-3c85-4b1f-b108-f13ce0eb3210] does not support precompilation but is imported by a module that does.
# └ @ Base loading.jl:1030
# ┌ Info: Skipping precompilation since __precompile__(false). Importing Pixman_jll [30392449-352a-5448-841d-b1acce4e97dc].
# └ @ Base loading.jl:1047
# ┌ Info: Precompiling libpng_jll [b53b4c65-9356-5827-b1ea-8c7a1a84506f]
# └ @ Base loading.jl:1342
# ┌ Warning: Module JLLWrappers with build ID 14418454654031536 is missing from the cache.
# │ This may mean JLLWrappers [692b3bcd-3c85-4b1f-b108-f13ce0eb3210] does not support precompilation but is imported by a module that does.
# └ @ Base loading.jl:1030
# ┌ Info: Skipping precompilation since __precompile__(false). Importing libpng_jll [b53b4c65-9356-5827-b1ea-8c7a1a84506f].
# └ @ Base loading.jl:1047
# ┌ Info: Precompiling Fontconfig_jll [a3f928ae-7b40-5064-980b-68af3947d34b]
# └ @ Base loading.jl:1342
# ┌ Warning: Module JLLWrappers with build ID 14418454654031536 is missing from the cache.
# │ This may mean JLLWrappers [692b3bcd-3c85-4b1f-b108-f13ce0eb3210] does not support precompilation but is imported by a module that does.
# └ @ Base loading.jl:1030
# ┌ Info: Skipping precompilation since __precompile__(false). Importing Fontconfig_jll [a3f928ae-7b40-5064-980b-68af3947d34b].
# └ @ Base loading.jl:1047
# ┌ Info: Precompiling Libuuid_jll [38a345b3-de98-5d2b-a5d3-14cd9215e700]
# └ @ Base loading.jl:1342
# ┌ Warning: Module JLLWrappers with build ID 14418454654031536 is missing from the cache.
# │ This may mean JLLWrappers [692b3bcd-3c85-4b1f-b108-f13ce0eb3210] does not support precompilation but is imported by a module that does.
# └ @ Base loading.jl:1030
# ┌ Info: Skipping precompilation since __precompile__(false). Importing Libuuid_jll [38a345b3-de98-5d2b-a5d3-14cd9215e700].
# └ @ Base loading.jl:1047
# ┌ Info: Precompiling Expat_jll [2e619515-83b5-522b-bb60-26c02a35a201]
# └ @ Base loading.jl:1342
# ┌ Warning: Module JLLWrappers with build ID 14418454654031536 is missing from the cache.
# │ This may mean JLLWrappers [692b3bcd-3c85-4b1f-b108-f13ce0eb3210] does not support precompilation but is imported by a module that does.
# └ @ Base loading.jl:1030
# ┌ Info: Skipping precompilation since __precompile__(false). Importing Expat_jll [2e619515-83b5-522b-bb60-26c02a35a201].
# └ @ Base loading.jl:1047
# ┌ Info: Precompiling Xorg_libXext_jll [1082639a-0dae-5f34-9b06-72781eeb8cb3]
# └ @ Base loading.jl:1342
# ┌ Warning: Module JLLWrappers with build ID 14418454654031536 is missing from the cache.
# │ This may mean JLLWrappers [692b3bcd-3c85-4b1f-b108-f13ce0eb3210] does not support precompilation but is imported by a module that does.
# └ @ Base loading.jl:1030
# ┌ Info: Skipping precompilation since __precompile__(false). Importing Xorg_libXext_jll [1082639a-0dae-5f34-9b06-72781eeb8cb3].
# └ @ Base loading.jl:1047
# ┌ Info: Precompiling Xorg_libX11_jll [4f6342f7-b3d2-589e-9d20-edeb45f2b2bc]
# └ @ Base loading.jl:1342
# ┌ Warning: Module JLLWrappers with build ID 14418454654031536 is missing from the cache.
# │ This may mean JLLWrappers [692b3bcd-3c85-4b1f-b108-f13ce0eb3210] does not support precompilation but is imported by a module that does.
# └ @ Base loading.jl:1030
# ┌ Info: Skipping precompilation since __precompile__(false). Importing Xorg_libX11_jll [4f6342f7-b3d2-589e-9d20-edeb45f2b2bc].
# └ @ Base loading.jl:1047
# ┌ Info: Precompiling Xorg_libxcb_jll [c7cfdc94-dc32-55de-ac96-5a1b8d977c5b]
# └ @ Base loading.jl:1342
# ┌ Warning: Module JLLWrappers with build ID 14418454654031536 is missing from the cache.
# │ This may mean JLLWrappers [692b3bcd-3c85-4b1f-b108-f13ce0eb3210] does not support precompilation but is imported by a module that does.
# └ @ Base loading.jl:1030
# ┌ Info: Skipping precompilation since __precompile__(false). Importing Xorg_libxcb_jll [c7cfdc94-dc32-55de-ac96-5a1b8d977c5b].
# └ @ Base loading.jl:1047
# ┌ Info: Precompiling XSLT_jll [aed1982a-8fda-507f-9586-7b0439959a61]
# └ @ Base loading.jl:1342
# ┌ Warning: Module JLLWrappers with build ID 14418454654031536 is missing from the cache.
# │ This may mean JLLWrappers [692b3bcd-3c85-4b1f-b108-f13ce0eb3210] does not support precompilation but is imported by a module that does.
# └ @ Base loading.jl:1030
# ┌ Info: Skipping precompilation since __precompile__(false). Importing XSLT_jll [aed1982a-8fda-507f-9586-7b0439959a61].
# └ @ Base loading.jl:1047
# ┌ Info: Precompiling Libgpg_error_jll [7add5ba3-2f88-524e-9cd5-f83b8a55f7b8]
# └ @ Base loading.jl:1342
# ┌ Warning: Module JLLWrappers with build ID 14418454654031536 is missing from the cache.
# │ This may mean JLLWrappers [692b3bcd-3c85-4b1f-b108-f13ce0eb3210] does not support precompilation but is imported by a module that does.
# └ @ Base loading.jl:1030
# ┌ Info: Skipping precompilation since __precompile__(false). Importing Libgpg_error_jll [7add5ba3-2f88-524e-9cd5-f83b8a55f7b8].
# └ @ Base loading.jl:1047
# ┌ Info: Precompiling Libgcrypt_jll [d4300ac3-e22c-5743-9152-c294e39db1e4]
# └ @ Base loading.jl:1342
# ┌ Warning: Module JLLWrappers with build ID 14418454654031536 is missing from the cache.
# │ This may mean JLLWrappers [692b3bcd-3c85-4b1f-b108-f13ce0eb3210] does not support precompilation but is imported by a module that does.
# └ @ Base loading.jl:1030
# ┌ Info: Skipping precompilation since __precompile__(false). Importing Libgcrypt_jll [d4300ac3-e22c-5743-9152-c294e39db1e4].
# └ @ Base loading.jl:1047
# ┌ Info: Precompiling Xorg_libXau_jll [0c0b7dd1-d40b-584c-a123-a41640f87eec]
# └ @ Base loading.jl:1342
# ┌ Warning: Module JLLWrappers with build ID 14418454654031536 is missing from the cache.
# │ This may mean JLLWrappers [692b3bcd-3c85-4b1f-b108-f13ce0eb3210] does not support precompilation but is imported by a module that does.
# └ @ Base loading.jl:1030
# ┌ Info: Skipping precompilation since __precompile__(false). Importing Xorg_libXau_jll [0c0b7dd1-d40b-584c-a123-a41640f87eec].
# └ @ Base loading.jl:1047
# ┌ Info: Precompiling Xorg_libXdmcp_jll [a3789734-cfe1-5b06-b2d0-1dd0d9d62d05]
# └ @ Base loading.jl:1342
# ┌ Warning: Module JLLWrappers with build ID 14418454654031536 is missing from the cache.
# │ This may mean JLLWrappers [692b3bcd-3c85-4b1f-b108-f13ce0eb3210] does not support precompilation but is imported by a module that does.
# └ @ Base loading.jl:1030
# ┌ Info: Skipping precompilation since __precompile__(false). Importing Xorg_libXdmcp_jll [a3789734-cfe1-5b06-b2d0-1dd0d9d62d05].
# └ @ Base loading.jl:1047
# ┌ Info: Precompiling Xorg_libpthread_stubs_jll [14d82f49-176c-5ed1-bb49-ad3f5cbd8c74]
# └ @ Base loading.jl:1342
# ┌ Warning: Module JLLWrappers with build ID 14418454654031536 is missing from the cache.
# │ This may mean JLLWrappers [692b3bcd-3c85-4b1f-b108-f13ce0eb3210] does not support precompilation but is imported by a module that does.
# └ @ Base loading.jl:1030
# ┌ Info: Skipping precompilation since __precompile__(false). Importing Xorg_libpthread_stubs_jll [14d82f49-176c-5ed1-bb49-ad3f5cbd8c74].
# └ @ Base loading.jl:1047
# ┌ Info: Precompiling Xorg_xtrans_jll [c5fb5394-a638-5e4d-96e5-b29de1b5cf10]
# └ @ Base loading.jl:1342
# ┌ Warning: Module JLLWrappers with build ID 14418454654031536 is missing from the cache.
# │ This may mean JLLWrappers [692b3bcd-3c85-4b1f-b108-f13ce0eb3210] does not support precompilation but is imported by a module that does.
# └ @ Base loading.jl:1030
# ┌ Info: Skipping precompilation since __precompile__(false). Importing Xorg_xtrans_jll [c5fb5394-a638-5e4d-96e5-b29de1b5cf10].
# └ @ Base loading.jl:1047
# ┌ Info: Precompiling Xorg_libXrender_jll [ea2f1a96-1ddc-540d-b46f-429655e07cfa]
# └ @ Base loading.jl:1342
# ┌ Warning: Module JLLWrappers with build ID 14418454654031536 is missing from the cache.
# │ This may mean JLLWrappers [692b3bcd-3c85-4b1f-b108-f13ce0eb3210] does not support precompilation but is imported by a module that does.
# └ @ Base loading.jl:1030
# ┌ Info: Skipping precompilation since __precompile__(false). Importing Xorg_libXrender_jll [ea2f1a96-1ddc-540d-b46f-429655e07cfa].
# └ @ Base loading.jl:1047
# ┌ Info: Precompiling LZO_jll [dd4b983a-f0e5-5f8d-a1b7-129d4a5fb1ac]
# └ @ Base loading.jl:1342
# ┌ Warning: Module JLLWrappers with build ID 14418454654031536 is missing from the cache.
# │ This may mean JLLWrappers [692b3bcd-3c85-4b1f-b108-f13ce0eb3210] does not support precompilation but is imported by a module that does.
# └ @ Base loading.jl:1030
# ┌ Info: Skipping precompilation since __precompile__(false). Importing LZO_jll [dd4b983a-f0e5-5f8d-a1b7-129d4a5fb1ac].
# └ @ Base loading.jl:1047
# ┌ Info: Precompiling Graphite2_jll [3b182d85-2403-5c21-9c21-1e1f0cc25472]
# └ @ Base loading.jl:1342
# ┌ Warning: Module JLLWrappers with build ID 14418454654031536 is missing from the cache.
# │ This may mean JLLWrappers [692b3bcd-3c85-4b1f-b108-f13ce0eb3210] does not support precompilation but is imported by a module that does.
# └ @ Base loading.jl:1030
# ┌ Info: Skipping precompilation since __precompile__(false). Importing Graphite2_jll [3b182d85-2403-5c21-9c21-1e1f0cc25472].
# └ @ Base loading.jl:1047
# ┌ Info: Precompiling libfdk_aac_jll [f638f0a6-7fb0-5443-88ba-1cc74229b280]
# └ @ Base loading.jl:1342
# ┌ Warning: Module JLLWrappers with build ID 14418454654031536 is missing from the cache.
# │ This may mean JLLWrappers [692b3bcd-3c85-4b1f-b108-f13ce0eb3210] does not support precompilation but is imported by a module that does.
# └ @ Base loading.jl:1030
# ┌ Info: Skipping precompilation since __precompile__(false). Importing libfdk_aac_jll [f638f0a6-7fb0-5443-88ba-1cc74229b280].
# └ @ Base loading.jl:1047
# ┌ Info: Precompiling LAME_jll [c1c5ebd0-6772-5130-a774-d5fcae4a789d]
# └ @ Base loading.jl:1342
# ┌ Warning: Module JLLWrappers with build ID 14418454654031536 is missing from the cache.
# │ This may mean JLLWrappers [692b3bcd-3c85-4b1f-b108-f13ce0eb3210] does not support precompilation but is imported by a module that does.
# └ @ Base loading.jl:1030
# ┌ Info: Skipping precompilation since __precompile__(false). Importing LAME_jll [c1c5ebd0-6772-5130-a774-d5fcae4a789d].
# └ @ Base loading.jl:1047
# ┌ Info: Precompiling libvorbis_jll [f27f6e37-5d2b-51aa-960f-b287f2bc3b7a]
# └ @ Base loading.jl:1342
# ┌ Warning: Module JLLWrappers with build ID 14418454654031536 is missing from the cache.
# │ This may mean JLLWrappers [692b3bcd-3c85-4b1f-b108-f13ce0eb3210] does not support precompilation but is imported by a module that does.
# └ @ Base loading.jl:1030
# ┌ Info: Skipping precompilation since __precompile__(false). Importing libvorbis_jll [f27f6e37-5d2b-51aa-960f-b287f2bc3b7a].
# └ @ Base loading.jl:1047
# ┌ Info: Precompiling Ogg_jll [e7412a2a-1a6e-54c0-be00-318e2571c051]
# └ @ Base loading.jl:1342
# ┌ Warning: Module JLLWrappers with build ID 14418454654031536 is missing from the cache.
# │ This may mean JLLWrappers [692b3bcd-3c85-4b1f-b108-f13ce0eb3210] does not support precompilation but is imported by a module that does.
# └ @ Base loading.jl:1030
# ┌ Info: Skipping precompilation since __precompile__(false). Importing Ogg_jll [e7412a2a-1a6e-54c0-be00-318e2571c051].
# └ @ Base loading.jl:1047
# ┌ Info: Precompiling x264_jll [1270edf5-f2f9-52d2-97e9-ab00b5d0237a]
# └ @ Base loading.jl:1342
# ┌ Warning: Module JLLWrappers with build ID 14418454654031536 is missing from the cache.
# │ This may mean JLLWrappers [692b3bcd-3c85-4b1f-b108-f13ce0eb3210] does not support precompilation but is imported by a module that does.
# └ @ Base loading.jl:1030
# ┌ Info: Skipping precompilation since __precompile__(false). Importing x264_jll [1270edf5-f2f9-52d2-97e9-ab00b5d0237a].
# └ @ Base loading.jl:1047
# ┌ Info: Precompiling x265_jll [dfaa095f-4041-5dcd-9319-2fabd8486b76]
# └ @ Base loading.jl:1342
# ┌ Warning: Module JLLWrappers with build ID 14418454654031536 is missing from the cache.
# │ This may mean JLLWrappers [692b3bcd-3c85-4b1f-b108-f13ce0eb3210] does not support precompilation but is imported by a module that does.
# └ @ Base loading.jl:1030
# ┌ Info: Skipping precompilation since __precompile__(false). Importing x265_jll [dfaa095f-4041-5dcd-9319-2fabd8486b76].
# └ @ Base loading.jl:1047
# ┌ Info: Precompiling OpenSSL_jll [458c3c95-2e84-50aa-8efc-19380b2a3a95]
# └ @ Base loading.jl:1342
# ┌ Warning: Module JLLWrappers with build ID 14418454654031536 is missing from the cache.
# │ This may mean JLLWrappers [692b3bcd-3c85-4b1f-b108-f13ce0eb3210] does not support precompilation but is imported by a module that does.
# └ @ Base loading.jl:1030
# ┌ Info: Skipping precompilation since __precompile__(false). Importing OpenSSL_jll [458c3c95-2e84-50aa-8efc-19380b2a3a95].
# └ @ Base loading.jl:1047
# ┌ Info: Precompiling Opus_jll [91d4177d-7536-5919-b921-800302f37372]
# └ @ Base loading.jl:1342
# ┌ Warning: Module JLLWrappers with build ID 14418454654031536 is missing from the cache.
# │ This may mean JLLWrappers [692b3bcd-3c85-4b1f-b108-f13ce0eb3210] does not support precompilation but is imported by a module that does.
# └ @ Base loading.jl:1030
# ┌ Info: Skipping precompilation since __precompile__(false). Importing Opus_jll [91d4177d-7536-5919-b921-800302f37372].
# └ @ Base loading.jl:1047
# ┌ Info: Precompiling PlotUtils [995b91a9-d308-5afd-9ec6-746e21dbc043]
# └ @ Base loading.jl:1342
# ┌ Warning: Module SpecialFunctions with build ID 23994285156318024 is missing from the cache.
# │ This may mean SpecialFunctions [276daf66-3868-5448-9aa4-cd146d93841b] does not support precompilation but is imported by a module that does.
# └ @ Base loading.jl:1030
# ┌ Warning: Module SpecialFunctions with build ID 23994285156318024 is missing from the cache.
# │ This may mean SpecialFunctions [276daf66-3868-5448-9aa4-cd146d93841b] does not support precompilation but is imported by a module that does.
# └ @ Base loading.jl:1030
# ┌ Warning: Module SpecialFunctions with build ID 23994285156318024 is missing from the cache.
# │ This may mean SpecialFunctions [276daf66-3868-5448-9aa4-cd146d93841b] does not support precompilation but is imported by a module that does.
# └ @ Base loading.jl:1030
# ┌ Warning: Module SpecialFunctions with build ID 23994285156318024 is missing from the cache.
# │ This may mean SpecialFunctions [276daf66-3868-5448-9aa4-cd146d93841b] does not support precompilation but is imported by a module that does.
# └ @ Base loading.jl:1030
# ┌ Info: Skipping precompilation since __precompile__(false). Importing PlotUtils [995b91a9-d308-5afd-9ec6-746e21dbc043].
# └ @ Base loading.jl:1047
# ┌ Info: Precompiling ColorSchemes [35d6a980-a343-548e-a6ea-1d62b119f2f4]
# └ @ Base loading.jl:1342
# ┌ Warning: Module SpecialFunctions with build ID 23994285156318024 is missing from the cache.
# │ This may mean SpecialFunctions [276daf66-3868-5448-9aa4-cd146d93841b] does not support precompilation but is imported by a module that does.
# └ @ Base loading.jl:1030
# ┌ Warning: Module SpecialFunctions with build ID 23994285156318024 is missing from the cache.
# │ This may mean SpecialFunctions [276daf66-3868-5448-9aa4-cd146d93841b] does not support precompilation but is imported by a module that does.
# └ @ Base loading.jl:1030
# ┌ Info: Skipping precompilation since __precompile__(false). Importing ColorSchemes [35d6a980-a343-548e-a6ea-1d62b119f2f4].
# └ @ Base loading.jl:1047
# ┌ Info: Precompiling ColorVectorSpace [c3611d14-8923-5661-9e6a-0046d554d3a4]
# └ @ Base loading.jl:1342
# ┌ Warning: Module SpecialFunctions with build ID 23994285156318024 is missing from the cache.
# │ This may mean SpecialFunctions [276daf66-3868-5448-9aa4-cd146d93841b] does not support precompilation but is imported by a module that does.
# └ @ Base loading.jl:1030
# ┌ Info: Skipping precompilation since __precompile__(false). Importing ColorVectorSpace [c3611d14-8923-5661-9e6a-0046d554d3a4].
# └ @ Base loading.jl:1047
# ┌ Info: Precompiling PlotThemes [ccf2f8ad-2431-5c83-bf29-c5338b663b6a]
# └ @ Base loading.jl:1342
# ┌ Warning: Module PlotUtils with build ID 23994333291354841 is missing from the cache.
# │ This may mean PlotUtils [995b91a9-d308-5afd-9ec6-746e21dbc043] does not support precompilation but is imported by a module that does.
# └ @ Base loading.jl:1030
# ┌ Info: Skipping precompilation since __precompile__(false). Importing PlotThemes [ccf2f8ad-2431-5c83-bf29-c5338b663b6a].
# └ @ Base loading.jl:1047
# ┌ Info: Precompiling RecipesPipeline [01d81517-befc-4cb6-b9ec-a95719d0359c]
# └ @ Base loading.jl:1342
# ┌ Warning: Module PlotUtils with build ID 23994333291354841 is missing from the cache.
# │ This may mean PlotUtils [995b91a9-d308-5afd-9ec6-746e21dbc043] does not support precompilation but is imported by a module that does.
# └ @ Base loading.jl:1030
# ┌ Info: Skipping precompilation since __precompile__(false). Importing RecipesPipeline [01d81517-befc-4cb6-b9ec-a95719d0359c].
# └ @ Base loading.jl:1047

# %%
Pkg.update()
# Out:
#     Updating registry at `/opt/julia/registries/General`
#     Updating git-repo `https://github.com/JuliaReliab/FaultTree.jl.git`
#     Updating git-repo `https://github.com/JuliaReliab/SparseMatrix.jl.git`
#     Updating git-repo `https://github.com/JuliaReliab/SymbolicMarkov.jl.git`
#     Updating git-repo `https://github.com/JuliaReliab/Deformula.jl.git`
#     Updating git-repo `https://github.com/JuliaReliab/Origin.jl.git`
#     Updating git-repo `https://github.com/JuliaReliab/NMarkov.jl.git`
#     Updating git-repo `https://github.com/JuliaReliab/PhaseTypeDistributions.jl.git`
#     Updating git-repo `https://github.com/JuliaReliab/SymbolicDiff.jl.git`
#     Updating git-repo `https://github.com/JuliaReliab/JuliaDot.jl.git`
#     Updating git-repo `https://github.com/JuliaReliab/DD.jl.git`
#    Installed PlotUtils ─────────────── v1.3.0
#    Installed SpecialFunctions ──────── v2.1.6
#    Installed IJulia ────────────────── v1.23.3
#    Installed StatsBase ─────────────── v0.33.18
#    Installed Plots ─────────────────── v1.31.1
#    Installed HDF5 ──────────────────── v0.16.10
#    Installed Distributions ─────────── v0.25.64
#    Installed DataFrames ────────────── v1.3.4
#    Installed PDMats ────────────────── v0.11.14
#    Installed IntegralArrays ────────── v0.1.5
#    Installed Preferences ───────────── v1.3.0
#    Installed OffsetArrays ──────────── v1.12.7
#    Installed ImageMorphology ───────── v0.3.2
#    Installed DataAPI ───────────────── v1.10.0
#    Installed HypergeometricFunctions ─ v0.3.10
#    Installed FillArrays ────────────── v0.13.2
#    Installed StatsAPI ──────────────── v1.4.0
#    Installed CEnum ─────────────────── v0.4.2
#    Installed Images ────────────────── v0.25.2
#    Installed InverseFunctions ──────── v0.1.7
#    Installed Rotations ─────────────── v1.3.1
#    Installed Graphs ────────────────── v1.7.1
#    Installed ImageIO ───────────────── v0.6.6
#    Installed FFTW ──────────────────── v1.5.0
#    Installed XML2_jll ──────────────── v2.9.14+0
#    Installed ColorVectorSpace ──────── v0.9.9
#    Installed NearestNeighbors ──────── v0.4.11
#    Installed ChainRulesCore ────────── v1.15.1
#    Installed GR_jll ────────────────── v0.64.4+0
#    Installed Parsers ───────────────── v2.3.2
#    Installed Graphics ──────────────── v1.1.2
#    Installed PNGFiles ──────────────── v0.3.16
#    Installed DataStructures ────────── v0.18.13
#    Installed Latexify ──────────────── v0.15.15
#    Installed ChangesOfVariables ────── v0.1.3
#    Installed OpenSSL_jll ───────────── v1.1.16+0
#    Installed IntervalSets ──────────── v0.7.1
#    Installed InlineStrings ─────────── v1.1.3
#    Installed StatsFuns ─────────────── v1.0.1
#    Installed MbedTLS ───────────────── v1.1.0
#    Installed Libtiff_jll ───────────── v4.4.0+0
#    Installed Compat ────────────────── v3.45.0
#    Installed LogExpFunctions ───────── v0.3.15
#    Installed ColorTypes ────────────── v0.11.4
#    Installed GR ────────────────────── v0.64.4
#    Installed ImageCore ─────────────── v0.9.4
#    Installed ColorSchemes ──────────── v3.19.0
#    Installed StaticArraysCore ──────── v1.0.1
#    Installed ImageQualityIndexes ───── v0.3.1
#    Installed AbstractFFTs ──────────── v1.2.1
#    Installed StructArrays ──────────── v0.6.11
#    Installed LazyModules ───────────── v0.3.1
#    Installed StaticArrays ──────────── v1.5.0
#    Installed ImageDistances ────────── v0.2.16
#    Installed Interpolations ────────── v0.13.6
#    Installed PooledArrays ──────────── v1.4.2
#    Installed SentinelArrays ────────── v1.3.13
#    Installed AxisArrays ────────────── v0.4.6
#    Installed TiffImages ────────────── v0.6.0
#    Installed Quaternions ───────────── v0.5.6
#    Installed FileIO ────────────────── v1.14.0
#    Installed ImageShow ─────────────── v0.3.6
#     Updating `/opt/julia/environments/v1.6/Project.toml`
#   [a93c6f00] ↑ DataFrames v1.3.2 ⇒ v1.3.4
#   [31c24e10] ↑ Distributions v0.25.53 ⇒ v0.25.64
#   [f67ccb44] ↑ HDF5 v0.16.6 ⇒ v0.16.10
#   [7073ff75] ↑ IJulia v1.23.2 ⇒ v1.23.3
#   [c5cca998] ~ NMarkov v0.3.4 `https://github.com/JuliaReliab/NMarkov.jl.git#master` ⇒ v0.3.5 `https://github.com/JuliaReliab/NMarkov.jl.git#master`
#   [6af5a0ae] ~ PhaseTypeDistributions v0.2.6 `https://github.com/JuliaReliab/PhaseTypeDistributions.jl.git#master` ⇒ v0.2.7 `https://github.com/JuliaReliab/PhaseTypeDistributions.jl.git#master`
#   [91a5bcdd] ↑ Plots v1.27.5 ⇒ v1.31.1
#   [b2a93422] ~ SparseMatrix v0.2.3 `https://github.com/JuliaReliab/SparseMatrix.jl.git#master` ⇒ v0.3.3 `https://github.com/JuliaReliab/SparseMatrix.jl.git#master`
#   [276daf66] ↑ SpecialFunctions v2.1.4 ⇒ v2.1.6
#   [29f2b557] ~ SymbolicMarkov v0.7.6 `https://github.com/JuliaReliab/SymbolicMarkov.jl.git#main` ⇒ v0.7.7 `https://github.com/JuliaReliab/SymbolicMarkov.jl.git#main`
#     Updating `/opt/julia/environments/v1.6/Manifest.toml`
#   [621f4979] ↑ AbstractFFTs v1.1.0 ⇒ v1.2.1
#   [4fba245c] - ArrayInterface v5.0.7
#   [39de3d68] ↑ AxisArrays v0.4.5 ⇒ v0.4.6
#   [fa961155] ↑ CEnum v0.4.1 ⇒ v0.4.2
#   [d360d2e6] ↑ ChainRulesCore v1.14.0 ⇒ v1.15.1
#   [9e997f8a] ↑ ChangesOfVariables v0.1.2 ⇒ v0.1.3
#   [35d6a980] ↑ ColorSchemes v3.17.1 ⇒ v3.19.0
#   [3da002f7] ↑ ColorTypes v0.11.0 ⇒ v0.11.4
#   [c3611d14] ↑ ColorVectorSpace v0.9.8 ⇒ v0.9.9
#   [34da2185] ↑ Compat v3.42.0 ⇒ v3.45.0
#   [9a962f9c] ↑ DataAPI v1.9.0 ⇒ v1.10.0
#   [a93c6f00] ↑ DataFrames v1.3.2 ⇒ v1.3.4
#   [864edb3b] ↑ DataStructures v0.18.11 ⇒ v0.18.13
#   [31c24e10] ↑ Distributions v0.25.53 ⇒ v0.25.64
#   [da5c29d0] - EllipsisNotation v1.5.0
#   [7a1cc6ca] ↑ FFTW v1.4.6 ⇒ v1.5.0
#   [5789e2e9] ↑ FileIO v1.13.0 ⇒ v1.14.0
#   [1a297f60] ↑ FillArrays v0.12.8 ⇒ v0.13.2
#   [28b8d3ca] ↑ GR v0.64.2 ⇒ v0.64.4
#   [a2bd30eb] ↑ Graphics v1.1.1 ⇒ v1.1.2
#   [86223c79] ↑ Graphs v1.6.0 ⇒ v1.7.1
#   [f67ccb44] ↑ HDF5 v0.16.6 ⇒ v0.16.10
#   [cd3eb016] ↑ HTTP v0.8.19 ⇒ v0.9.17
#   [34004b35] ↑ HypergeometricFunctions v0.3.8 ⇒ v0.3.10
#   [7073ff75] ↑ IJulia v1.23.2 ⇒ v1.23.3
#   [615f187c] - IfElse v0.1.1
#   [a09fc81d] ↑ ImageCore v0.9.3 ⇒ v0.9.4
#   [51556ac3] ↑ ImageDistances v0.2.15 ⇒ v0.2.16
#   [82e4d734] ↑ ImageIO v0.6.1 ⇒ v0.6.6
#   [6218d12a] ↑ ImageMagick v1.2.1 ⇒ v1.2.2
#   [787d08f9] ↑ ImageMorphology v0.3.1 ⇒ v0.3.2
#   [2996bd0c] ↑ ImageQualityIndexes v0.3.0 ⇒ v0.3.1
#   [4e3cecfd] ↑ ImageShow v0.3.3 ⇒ v0.3.6
#   [916415d5] ↑ Images v0.25.1 ⇒ v0.25.2
#   [842dd82b] ↑ InlineStrings v1.1.2 ⇒ v1.1.3
#   [1d092043] ↑ IntegralArrays v0.1.3 ⇒ v0.1.5
#   [a98d9a8b] ↑ Interpolations v0.13.5 ⇒ v0.13.6
#   [8197267c] ↑ IntervalSets v0.5.4 ⇒ v0.7.1
#   [3587e190] ↑ InverseFunctions v0.1.3 ⇒ v0.1.7
#   [23fbe1c1] ↑ Latexify v0.15.14 ⇒ v0.15.15
#   [8cdb02fc] + LazyModules v0.3.1
#   [2ab3a3ac] ↑ LogExpFunctions v0.3.10 ⇒ v0.3.15
#   [739be429] ↑ MbedTLS v1.0.3 ⇒ v1.1.0
#   [c5cca998] ~ NMarkov v0.3.4 `https://github.com/JuliaReliab/NMarkov.jl.git#master` ⇒ v0.3.5 `https://github.com/JuliaReliab/NMarkov.jl.git#master`
#   [77ba4419] ↑ NaNMath v0.3.7 ⇒ v1.0.0
#   [b8a86587] ↑ NearestNeighbors v0.4.10 ⇒ v0.4.11
#   [6fe1bfb0] ↑ OffsetArrays v1.10.8 ⇒ v1.12.7
#   [90014a1f] ↑ PDMats v0.11.7 ⇒ v0.11.14
#   [f57f5aa1] ↑ PNGFiles v0.3.14 ⇒ v0.3.16
#   [69de0a69] ↑ Parsers v2.2.4 ⇒ v2.3.2
#   [6af5a0ae] ~ PhaseTypeDistributions v0.2.6 `https://github.com/JuliaReliab/PhaseTypeDistributions.jl.git#master` ⇒ v0.2.7 `https://github.com/JuliaReliab/PhaseTypeDistributions.jl.git#master`
#   [995b91a9] ↑ PlotUtils v1.2.0 ⇒ v1.3.0
#   [91a5bcdd] ↑ Plots v1.27.5 ⇒ v1.31.1
#   [2dfb63ee] ↑ PooledArrays v1.4.1 ⇒ v1.4.2
#   [21216c6a] ↑ Preferences v1.2.5 ⇒ v1.3.0
#   [94ee1d12] ↑ Quaternions v0.5.4 ⇒ v0.5.6
#   [6038ab10] ↑ Rotations v1.3.0 ⇒ v1.3.1
#   [91c51154] ↑ SentinelArrays v1.3.12 ⇒ v1.3.13
#   [b2a93422] ~ SparseMatrix v0.2.3 `https://github.com/JuliaReliab/SparseMatrix.jl.git#master` ⇒ v0.3.3 `https://github.com/JuliaReliab/SparseMatrix.jl.git#master`
#   [276daf66] ↑ SpecialFunctions v2.1.4 ⇒ v2.1.6
#   [aedffcd0] - Static v0.6.0
#   [90137ffa] ↑ StaticArrays v1.4.3 ⇒ v1.5.0
#   [1e83bf80] + StaticArraysCore v1.0.1
#   [82ae8749] ↑ StatsAPI v1.2.1 ⇒ v1.4.0
#   [2913bbd2] ↑ StatsBase v0.33.16 ⇒ v0.33.18
#   [4c63d2b9] ↑ StatsFuns v0.9.17 ⇒ v1.0.1
#   [09ab397b] ↑ StructArrays v0.6.5 ⇒ v0.6.11
#   [29f2b557] ~ SymbolicMarkov v0.7.6 `https://github.com/JuliaReliab/SymbolicMarkov.jl.git#main` ⇒ v0.7.7 `https://github.com/JuliaReliab/SymbolicMarkov.jl.git#main`
#   [9ac5f52a] + Tectonic v0.8.0
#   [731e570b] ↑ TiffImages v0.5.4 ⇒ v0.6.0
#   [37f6aa50] ↑ TikzPictures v3.2.0 ⇒ v3.4.2
#   [5c2747f8] + URIs v1.3.0
#   [d2c73de3] ↑ GR_jll v0.64.2+0 ⇒ v0.64.4+0
#   [61579ee1] - Ghostscript_jll v9.55.0+0
#   [c73af94c] ↓ ImageMagick_jll v6.9.12+2 ⇒ v6.9.10-12+3
#   [89763e89] ↑ Libtiff_jll v4.3.0+1 ⇒ v4.4.0+0
#   [458c3c95] ↑ OpenSSL_jll v1.1.14+0 ⇒ v1.1.16+0
#   [9c32591e] ↓ Poppler_jll v21.9.0+0 ⇒ v0.87.0+2
#   [02c8fc9c] ↑ XML2_jll v2.9.12+0 ⇒ v2.9.14+0
#     Building HDF5 ──→ `/opt/julia/scratchspaces/44cfe95a-1eb2-52ea-b672-e2afdf69b78f/9ffc57b9bb643bf3fce34f3daf9ff506ed2d8b7a/build.log`
#     Building IJulia → `/opt/julia/scratchspaces/44cfe95a-1eb2-52ea-b672-e2afdf69b78f/98ab633acb0fe071b671f6c1785c46cd70bb86bd/build.log`
#     Building GR ────→ `/opt/julia/scratchspaces/44cfe95a-1eb2-52ea-b672-e2afdf69b78f/c98aea696662d09e215ef7cda5296024a9646c75/build.log`
# Precompiling project...
#   ✓ DataAPI
#   ✓ NaNMath
#   ✓ StaticArraysCore
#   ✓ LazyModules
#   ✓ StatsAPI
#   ✓ Preferences
#   ✓ InverseFunctions
#   ✓ CEnum
#   ✓ PDMats
#   ✓ IntervalSets
#   ✓ SparseMatrix
#   ✓ Missings
#   ✓ PooledArrays
#   ✓ SentinelArrays
#   ✓ InlineStrings
#   ✓ FillArrays
#   ✓ Compat
#   ✓ JLLWrappers
#   ✓ MbedTLS
#   ✓ OffsetArrays
#   ✓ DensityInterface
#   ✓ Distances
#   ✓ Tables
#   ✓ Latexify
#   ✓ SymbolicDiff
#   ✓ AxisArrays
#   ✓ FriBidi_jll
#   ✓ Libuuid_jll
#   ✓ OpenSSL_jll
#   ✓ libfdk_aac_jll
#   ✓ Zstd_jll
#   ✓ Pixman_jll
#   ✓ FileIO
#   ✓ ChainRulesCore
#   ✓ ColorTypes
#   ✓ FilePathsBase
#   ✓ WeakRefStrings
#   ✓ Libmount_jll
#   ✓ Expat_jll
#   ✓ JpegTurbo_jll
#   ✓ Libiconv_jll
#   ✓ IntelOpenMP_jll
#   ✓ Xorg_libXau_jll
#   ✓ libpng_jll
#   ✓ Xorg_libXdmcp_jll
#   ✓ Ogg_jll
#   ✓ x264_jll
#   ✓ DataStructures
#   ✓ FFTW_jll
#   ✓ Xorg_xtrans_jll
#   ✓ libsodium_jll
#   ✓ Wayland_protocols_jll
#   ✓ Libffi_jll
#   ✓ LAME_jll
#   ✓ Libgpg_error_jll
#   ✓ x265_jll
#   ✓ PCRE_jll
#   ✓ Bzip2_jll
#   ✓ LZO_jll
#   ✓ Opus_jll
#   ✓ libsixel_jll
#   ✓ OpenSpecFun_jll
#   ✓ EarCut_jll
#   ✓ Rmath_jll
#   ✓ TiledIteration
#   ✓ Graphite2_jll
#   ✓ Imath_jll
#   ✓ PaddedViews
#   ✓ CatIndices
#   ✓ Xorg_libpthread_stubs_jll
#   ✓ StackViews
#   ✓ LERC_jll
#   ✓ HDF5_jll
#   ✓ AbstractFFTs
#   ✓ FaultTree
#   ✓ IntegralArrays
#   ✓ SortingAlgorithms
#   ✓ MKL_jll
#   ✓ QOI
#   ✓ ChangesOfVariables
#   ✓ XML2_jll
#   ✓ libvorbis_jll
#   ✓ MosaicViews
#   ✓ Rmath
#   ✓ Libgcrypt_jll
#   ✓ HTTP
#   ✓ QuadGK
#   ✓ ZeroMQ_jll
#   ✓ FreeType2_jll
#   ✓ OpenEXR_jll
#   ✓ Libtiff_jll
#   ✓ XSLT_jll
#   ✓ Gettext_jll
#   ✓ Wayland_jll
#   ✓ ImageMagick_jll
#   ✓ ZMQ
#   ✓ Fontconfig_jll
#   ✓ LittleCMS_jll
#   ✓ StaticArrays
#   ✓ LogExpFunctions
#   ✓ Colors
#   ✓ Xorg_libxcb_jll
#   ✓ Glib_jll
#   ✓ OpenJpeg_jll
#   ✓ PrettyTables
#   ✓ IJulia
#   ✓ NearestNeighbors
#   ✓ Contour
#   ✓ StructArrays
#   ✓ HDF5
#   ✓ RegionTrees
#   ✓ CoordinateTransformations
#   ✓ ArnoldiMethod
#   ✓ CSV
#   ✓ Graphics
#   ✓ ColorBrewer
#   ✓ Xorg_libX11_jll
#   ✓ Xorg_xcb_util_jll
#   ✓ OpenEXR
#   ✓ FFTW
#   ✓ StatsBase
#   ✓ MAT
#   ✓ Xorg_libxkbfile_jll
#   ✓ Xorg_libXfixes_jll
#   ✓ Xorg_libXext_jll
#   ✓ Xorg_libXrender_jll
#   ✓ Interpolations
#   ✓ Xorg_xcb_util_image_jll
#   ✓ Xorg_xcb_util_keysyms_jll
#   ✓ Xorg_xcb_util_wm_jll
#   ✓ Xorg_xcb_util_renderutil_jll
#   ✓ FFTViews
#   ✓ Libglvnd_jll
#   ✓ Xorg_xkbcomp_jll
#   ✓ Xorg_libXi_jll
#   ✓ Cairo_jll
#   ✓ Xorg_libXinerama_jll
#   ✓ Xorg_libXcursor_jll
#   ✓ Xorg_libXrandr_jll
#   ✓ Xorg_xkeyboard_config_jll
#   ✓ SpecialFunctions
#   ✓ JLD2
#   ✓ HarfBuzz_jll
#   ✓ GLFW_jll
#   ✓ Poppler_jll
#   ✓ Clustering
#   ✓ xkbcommon_jll
#   ✓ TikzPictures
#   ✓ DualNumbers
#   ✓ libass_jll
#   ✓ Discretizers
#   ✓ Graphs
#   ✓ Qt5Base_jll
#   ✓ FFMPEG_jll
#   ✓ Quaternions
#   ✓ HypergeometricFunctions
#   ✓ FFMPEG
#   ✓ ColorVectorSpace
#   ✓ GeometryBasics
#   ✓ GR_jll
#   ✓ SimpleWeightedGraphs
#   ✓ MetaGraphs
#   ✓ StatsFuns
#   ✓ Rotations
#   ✓ GR
#   ✓ ColorSchemes
#   ✓ Distributions
#   ✓ PlotUtils
#   ✓ NMarkov
#   ✓ SymbolicMarkov
#   ✓ PhaseTypeDistributions
#   ✓ RecipesPipeline
#   ✓ PlotThemes
#   ✓ DataFrames
#   ✓ TiffImages
#   ✓ ImageCore
#   ✓ Netpbm
#   ✓ ImageMorphology
#   ✓ Sixel
#   ✓ JpegTurbo
#   ✓ ImageBase
#   ✓ PNGFiles
#   ✓ ImageMagick
#   ✓ ImageIO
#   ✓ ImageDistances
#   ✓ ImageShow
#   ✓ ImageAxes
#   ✓ ImageTransformations
#   ✓ ImageMetadata
#   ✓ ImageContrastAdjustment
#   ✓ ImageFiltering
#   ✓ ImageQualityIndexes
#   ✓ ImageSegmentation
#   ✓ Images
#   ✓ Plots
#   ✓ PGFPlots
#   196 dependencies successfully precompiled in 65 seconds (62 already precompiled)
#   7 dependencies precompiled but different versions are currently loaded. Restart julia to access the new versions

# %% [markdown]
# # Example: SIFT-like system
#
# - p.184 in Red book
#
# ### SHARPE code
#
# ```
# * SIFT example
#
# func c(x, k) \
#   360/(360 + (k-1) * x)
# func r(x,k) \
#   k * x * c(x,k)
# func f(x,k) \
#   k * x * (1-c(x,k))
#
# markov SIFT
# 4-3 3-3 r(lambda,4)
# 3-3 2-3 r(lambda,3)
#
# 4-3 F f(lambda,4) + f(mu,3)
# 3-3 F f(lambda,3) + f(mu,3)
# 2-3 F (2 * lambda) + f(mu,3)
#
# 4-3 4-2 r(mu,3)
# 3-3 3-2 r(mu,3)
# 2-3 2-2 r(mu,3)
#
# 4-2 3-2 r(lambda,4)
# 3-2 2-2 r(lambda,3)
#
# 4-2 F (2 * mu) + f(lambda,4)
# 3-2 F (2 * mu) + f(lambda,3)
# 2-2 F (2 * mu) + (2 * lambda)
# end
# end
#
# bind
# lambda .0001
# mu .00001
# end
#
# expr mean(SIFT,F)
# expr variance(SIFT,F)
# expr value(10;SIFT,F)
# end
# ```

# %%
@macroexpand @markov SIFT(;lambda, mu) begin
    c(x,k) = 360/(360 + (k-1) * x)
    r(x,k) = k * x * c(x,k)
    f(x,k) = k * x * (1-c(x,k))
    @tr begin
        @s("4-3") => @s("3-3"), r(lambda,4)
        @s("3-3") => @s("2-3"), r(lambda,3)

        @s("4-3") => @s("F"), f(lambda,4) + f(mu,3)
        @s("3-3") => @s("F"), f(lambda,3) + f(mu,3)
        @s("2-3") => @s("F"), 2 * lambda + f(mu,3)

        @s("4-3") => @s("4-2"), r(mu,3)
        @s("3-3") => @s("3-2"), r(mu,3)
        @s("2-3") => @s("2-2"), r(mu,3)

        @s("4-2") => @s("3-2"), r(lambda,4)
        @s("3-2") => @s("2-2"), r(lambda,3)

        @s("4-2") => @s("F"), (2 * mu) + f(lambda,4)
        @s("3-2") => @s("F"), (2 * mu) + f(lambda,3)
        @s("2-2") => @s("F"), (2 * mu) + (2 * lambda)
    end
    @init begin
        @s("4-3"), 1
    end
    @reward :down begin
        @s("F"), 1
    end
end
# Out:
# :(function SIFT(; lambda, mu)
#       tmp = Markov()
#       #= In[7]:2 =#
#       c(x, k) = begin
#               #= In[7]:2 =#
#               360 / (360 + (k - 1) * x)
#           end
#       #= In[7]:3 =#
#       r(x, k) = begin
#               #= In[7]:3 =#
#               k * x * c(x, k)
#           end
#       #= In[7]:4 =#
#       f(x, k) = begin
#               #= In[7]:4 =#
#               k * x * (1 - c(x, k))
#           end
#       #= In[7]:5 =#
#       begin
#           #= In[7]:6 =#
#           trans!(tmp, Symbol("4-3"), Symbol("3-3"), r(lambda, 4))
#           #= In[7]:7 =#
#           trans!(tmp, Symbol("3-3"), Symbol("2-3"), r(lambda, 3))
#           #= In[7]:9 =#
#           trans!(tmp, Symbol("4-3"), Symbol("F"), f(lambda, 4) + f(mu, 3))
#           #= In[7]:10 =#
#           trans!(tmp, Symbol("3-3"), Symbol("F"), f(lambda, 3) + f(mu, 3))
#           #= In[7]:11 =#
#           trans!(tmp, Symbol("2-3"), Symbol("F"), 2lambda + f(mu, 3))
#           #= In[7]:13 =#
#           trans!(tmp, Symbol("4-3"), Symbol("4-2"), r(mu, 3))
#           #= In[7]:14 =#
#           trans!(tmp, Symbol("3-3"), Symbol("3-2"), r(mu, 3))
#           #= In[7]:15 =#
#           trans!(tmp, Symbol("2-3"), Symbol("2-2"), r(mu, 3))
#           #= In[7]:17 =#
#           trans!(tmp, Symbol("4-2"), Symbol("3-2"), r(lambda, 4))
#           #= In[7]:18 =#
#           trans!(tmp, Symbol("3-2"), Symbol("2-2"), r(lambda, 3))
#           #= In[7]:20 =#
#           trans!(tmp, Symbol("4-2"), Symbol("F"), 2mu + f(lambda, 4))
#           #= In[7]:21 =#
#           trans!(tmp, Symbol("3-2"), Symbol("F"), 2mu + f(lambda, 3))
#           #= In[7]:22 =#
#           trans!(tmp, Symbol("2-2"), Symbol("F"), 2mu + 2lambda)
#       end
#       #= In[7]:24 =#
#       begin
#           #= In[7]:25 =#
#           initial!(tmp, Symbol("4-3"), 1)
#       end
#       #= In[7]:27 =#
#       begin
#           #= In[7]:28 =#
#           reward!(tmp, :down, Symbol("F"), 1)
#       end
#       tmp
#   end)

# %%
begin
    lambda = 0.0001
    mu = 0.00001
end
# Out:
# 1.0e-5

# %%
# compute
#   mean(SIFT,F)
#   variance(SIFT,F)
#   value(10; SIFT, F)
#

# gen CTMC and PH
sift = ctmc(SIFT(lambda = lambda, mu = mu))
up = [x != 1 for x = sift.reward[:down]]
T = sift.Q[up,up]
alpha = sift.initv[up]
tmp = (-T)' \ alpha
siftm = sum(tmp)
tmp = (-T)' \ tmp
siftv = sum(tmp) * 2 - siftm^2
sift10 = exrt(10.0, sift, reward=:down)[1]
(siftm, siftv, sift10)
# Out:
# (10604.190777840504, 3.990485188959943e7, 3.7273559466670164e-8)

# %% [markdown]
# # Example: The ten processor example
#
# - p.187 in Red book
#
# ### SHARPE code
#
# ```
# markov 10proc(lam, mu, c)
# ...
# end
# ```

# %%
@markov model10proc(;lam, mu, c, K) begin
    for i = K:-1:2
        @tr @s(i) => @s(i-1), i*lam*c
        @tr @s(i) => @s(0), i*lam*(1-c)
    end
    @tr @s(1) => @s(0), lam
    for i = 1:K-1
        @tr @s(i) => @s(i+1), mu
    end
    @init @s(K), 1
    @reward :a begin
        @s(K), 1
    end
end
# Out:
# model10proc (generic function with 2 methods)

# %%
@bind begin
    lam = 1.0
    mu = 1.0
    c = 0.9999
end
K = 10
# Out:
# 10

# %%
tenproc = ctmc(model10proc(lam = lam, mu = mu, c = c, K = K))
# Out:
# "CTMCModel(2926725442712203260)"

# %%
seval(exrt(LinRange(0, 10, 100), tenproc, reward = :a))
# Out:
# 100-element Vector{Float64}:
#  1.0
#  0.3830645465949663
#  0.16153107553772378
#  0.07404714116313584
#  0.03635225553799549
#  0.018854421983638556
#  0.01022038743323745
#  0.005744040314660446
#  0.0033277017617644494
#  0.0019788839202512535
#  0.0012042087875139811
#  0.0007481430895357245
#  0.0004737029660688018
#  ⋮
#  2.0753109160150083e-8
#  1.982701344306784e-8
#  1.8942601136225316e-8
#  1.809793914490598e-8
#  1.7291193033922013e-8
#  1.6520620606148166e-8
#  1.5784566093255882e-8
#  1.508145487881577e-8
#  1.4409788685997998e-8
#  1.3768141172237441e-8
#  1.315515388175961e-8
#  1.2569532514045706e-8
